# %%
import codecs
import json
import re
import requests

from bs4 import BeautifulSoup

# %%
PATTERN = r"{}\s+=\s+JSON.parse\(\'(.*?)\'\)"

def fetch(url):

    with requests.get(url) as response:
        return response.text

def find_match(scripts, pattern):

    for script in scripts:
        match = re.search(pattern, script.string)
        if match:
            break
    return match

def decode_data(match):

    byte_data = codecs.escape_decode(match.group(1))
    json_data = json.loads(byte_data[0].decode("utf-8"))

    return json_data

def get_data(url):

    html = fetch(url)
    soup = BeautifulSoup(html, "html.parser")
    scripts = soup.find_all("script")

    pattern = re.compile(PATTERN.format('shotsData'))
    match = find_match(scripts, pattern)
    data = decode_data(match)
    return data


url = 'https://understat.com/match/14795'
data = get_data(url)

# %%
len(data['h'])
# Out:
# 19

# %%
timo_werner_data = data.get('season')[:2]

# %%
timo_werner_data
# Out:
# [{'position': 'FW',
#   'games': '34',
#   'goals': '6',
#   'shots': '77',
#   'time': '2515',
#   'xG': '13.167441369965672',
#   'assists': '8',
#   'xA': '6.30144178122282',
#   'key_passes': '33',
#   'season': '2020',
#   'team': 'Chelsea',
#   'yellow': '1',
#   'red': '0',
#   'npg': '6',
#   'npxG': '13.167441369965672',
#   'xGChain': '19.503117971122265',
#   'xGBuildup': '4.7621055180206895'},
#  {'position': 'FWL',
#   'games': '34',
#   'goals': '28',
#   'shots': '123',
#   'time': '2825',
#   'xG': '23.448496147990227',
#   'assists': '8',
#   'xA': '9.675973629578948',
#   'key_passes': '53',
#   'season': '2019',
#   'team': 'RasenBallsport Leipzig',
#   'yellow': '4',
#   'red': '0',
#   'npg': '25',
#   'npxG': '21.175246581435204',
#   'xGChain': '35.58640310168266',
#   'xGBuildup': '7.971801660954952'}]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from soccerplots.radar_chart import Radar

# %%
df = pd.DataFrame(timo_werner_data)

# %%
df = df.drop(['position','season'],axis=1)

# %%
df
# Out:
#   games goals shots  time                  xG assists                 xA  \
# 0    34     6    77  2515  13.167441369965672       8   6.30144178122282
# 1    34    28   123  2825  23.448496147990227       8  9.675973629578948
#
#   key_passes                    team yellow red npg                npxG  \
# 0         33                 Chelsea      1   0   6  13.167441369965672
# 1         53  RasenBallsport Leipzig      4   0  25  21.175246581435204
#
#               xGChain           xGBuildup
# 0  19.503117971122265  4.7621055180206895
# 1   35.58640310168266   7.971801660954952

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   games       2 non-null      object
#  1   goals       2 non-null      object
#  2   shots       2 non-null      object
#  3   time        2 non-null      object
#  4   xG          2 non-null      object
#  5   assists     2 non-null      object
#  6   xA          2 non-null      object
#  7   key_passes  2 non-null      object
#  8   team        2 non-null      object
#  9   yellow      2 non-null      object
#  10  red         2 non-null      object
#  11  npg         2 non-null      object
#  12  npxG        2 non-null      object
#  13  xGChain     2 non-null      object
#  14  xGBuildup   2 non-null      object
# dtypes: object(15)
# memory usage: 368.0+ bytes

# %%
df = df.rename(columns={'xG': 'xG-Expected Goals', 'xA': 'xA-Expected assists', 'xGBuildup': 'Total xG of every \npossession the player is \ninvolved in without \nkey passes and shots', 'xGChain': 'Total xG of every \npossession the player is \ninvolved in', 'npxG': 'Not penalty \nExpected Goals \nper 90 minutes', 'npg': 'Not penalty goals'})

# %%
df
# Out:
#   games goals shots  time   xG-Expected Goals assists xA-Expected assists  \
# 0    34     6    77  2515  13.167441369965672       8    6.30144178122282
# 1    34    28   123  2825  23.448496147990227       8   9.675973629578948
#
#   key_passes                    team yellow red Not penalty goals  \
# 0         33                 Chelsea      1   0                 6
# 1         53  RasenBallsport Leipzig      4   0                25
#
#   Not penalty \nExpected Goals \nper 90 minutes  \
# 0                            13.167441369965672
# 1                            21.175246581435204
#
#   Total xG of every \npossession the player is \ninvolved in  \
# 0                                 19.503117971122265
# 1                                  35.58640310168266
#
#   Total xG of every \npossession the player is \ninvolved in without \nkey passes and shots
# 0                                 4.7621055180206895
# 1                                  7.971801660954952

# %%
first_column = df.pop('team')

# %%
df.insert(0, 'Team', first_column)

# %%
df
# Out:
#                      Team games goals shots  time   xG-Expected Goals assists  \
# 0                 Chelsea    34     6    77  2515  13.167441369965672       8
# 1  RasenBallsport Leipzig    34    28   123  2825  23.448496147990227       8
#
#   xA-Expected assists key_passes yellow red Not penalty goals  \
# 0    6.30144178122282         33      1   0                 6
# 1   9.675973629578948         53      4   0                25
#
#   Not penalty \nExpected Goals \nper 90 minutes  \
# 0                            13.167441369965672
# 1                            21.175246581435204
#
#   Total xG of every \npossession the player is \ninvolved in  \
# 0                                 19.503117971122265
# 1                                  35.58640310168266
#
#   Total xG of every \npossession the player is \ninvolved in without \nkey passes and shots
# 0                                 4.7621055180206895
# 1                                  7.971801660954952

# %%
#get parameters
params = list(df.columns)
params = params[1:]
params
# Out:
# ['games',
#  'goals',
#  'shots',
#  'time',
#  'xG-Expected Goals',
#  'assists',
#  'xA-Expected assists',
#  'key_passes',
#  'yellow',
#  'red',
#  'Not penalty goals',
#  'Not penalty \nExpected Goals \nper 90 minutes',
#  'Total xG of every \npossession the player is \ninvolved in',
#  'Total xG of every \npossession the player is \ninvolved in without \nkey passes and shots']

# %%
#add ranges to list of tuple pairs
ranges = []
a_values = []
b_values = []

for x in params:
    print(x)
    a = min(df[params][x].astype(float).round(3))
    a = a - (a*.25)
    if not a:
        a=0
    
    b = max(df[params][x].astype(float).round(3))
    b = b + (b*.25)
    if not b:
        b=1
    
    ranges.append((round(a),round(b)))
    
for x in range(len(df['Team'])):
    if df['Team'][x] == 'Chelsea':
        a_values = df.iloc[x].values.tolist()
    if df['Team'][x] == 'RasenBallsport Leipzig':
        b_values = df.iloc[x].values.tolist()
a_values = a_values[1:]
b_values = b_values[1:]
a_values = [float(item) for item in a_values]
b_values = [float(item) for item in b_values]

# list_of_floats = [float(item) for item in a_list]
values = [a_values,b_values]
# Out:
# games
# goals
# shots
# time
# xG-Expected Goals
# assists
# xA-Expected assists
# key_passes
# yellow
# red
# Not penalty goals
# Not penalty
# Expected Goals
# per 90 minutes
# Total xG of every
# possession the player is
# involved in
# Total xG of every
# possession the player is
# involved in without
# key passes and shots

# %%
#title 

title = dict(
    title_name='Timo Werner',
    title_color = 'blue',
    subtitle_name = 'Chelsea',
    subtitle_color = 'blue',
    title_name_2='Timo Werner',
    title_color_2 = 'red',
    subtitle_name_2 = 'RasenBallsport Leipzig',
    subtitle_color_2 = 'red',
    title_fontsize = 18,
    subtitle_fontsize=15
)

endnote = 'Fasal'
print(ranges)
print(params)
print(values)
params = ['Games', 'Goals', 'Shots', 'Time', 'xG-Expected Goals', 'Assists', 'xA-Expected assists', 'Key passes', 'Yellow', 'Red', 'Not penalty goals', 'Not penalty \nExpected Goals \nper 90 minutes', 'Total xG of every \npossession the player is \ninvolved in', 'Total xG of every \npossession the player is \ninvolved in without \nkey passes and shots']
# Out:
# [(26, 42), (4, 35), (58, 154), (1886, 3531), (10, 29), (6, 10), (5, 12), (25, 66), (1, 5), (0, 1), (4, 31), (10, 26), (15, 44), (4, 10)]
# ['games', 'goals', 'shots', 'time', 'xG-Expected Goals', 'assists', 'xA-Expected assists', 'key_passes', 'yellow', 'red', 'Not penalty goals', 'Not penalty \nExpected Goals \nper 90 minutes', 'Total xG of every \npossession the player is \ninvolved in', 'Total xG of every \npossession the player is \ninvolved in without \nkey passes and shots']
# [[34.0, 6.0, 77.0, 2515.0, 13.167441369965672, 8.0, 6.30144178122282, 33.0, 1.0, 0.0, 6.0, 13.167441369965672, 19.503117971122265, 4.7621055180206895], [34.0, 28.0, 123.0, 2825.0, 23.448496147990227, 8.0, 9.675973629578948, 53.0, 4.0, 0.0, 25.0, 21.175246581435204, 35.58640310168266, 7.971801660954952]]

# %%
radar = Radar()

fig,ax = radar.plot_radar(ranges=ranges,params=params,values=values,filename='Timo Werner',
                         radar_color=['blue','red'],
                         alphas=[0.8, 0.5],title=title,endnote=endnote,
                         compare=True,rotation=45)
